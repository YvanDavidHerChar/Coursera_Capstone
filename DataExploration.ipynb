# %% [markdown]
# Choosing to download my data from https://domingomery.ing.puc.cl/material/gdxray/ it is quite challenging to be able to access the data in IBM Watson Studio as the number of images is quite high (8150). To explore the images, I uploaded some of the files I'll use as train. Specially the shuriken ones.  To be able to access them in a notebook (and not use the Watson Visual Recognition software) I uploaded some zip files with the images and without the readme files, so there are only images inside the files. I didn't want to use WVR as I think I want to do something different. You will see...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# B0050_shuriken/B0050_0001.png
# (861, 861)
# B0050_shuriken/B0050_0002.png
# (861, 861)
# B0050_shuriken/B0050_0003.png
# (861, 861)
# B0050_shuriken/B0050_0004.png
# (861, 861)
# B0050_shuriken/B0050_0005.png
# (861, 861)
# B0050_shuriken/B0050_0006.png
# (861, 861)
# B0050_shuriken/B0050_0007.png
# (861, 861)
# B0050_shuriken/B0050_0008.png
# (861, 861)
# B0050_shuriken/B0050_0009.png
# (861, 861)
# B0050_shuriken/B0050_0010.png
# (861, 861)
# B0050_shuriken/B0050_0011.png
# (861, 861)
# B0050_shuriken/B0050_0012.png
# (861, 861)
# B0050_shuriken/B0050_0013.png
# (861, 861)
# B0050_shuriken/B0050_0014.png
# (861, 861)
# B0050_shuriken/B0050_0015.png
# (861, 861)
# B0050_shuriken/B0050_0016.png
# (861, 861)
# B0050_shuriken/B0050_0017.png
# (861, 861)
# B0050_shuriken/B0050_0018.png
# (861, 861)
# B0050_shuriken/B0050_0019.png
# (861, 861)
# B0050_shuriken/B0050_0020.png
# (861, 861)
# B0050_shuriken/B0050_0021.png
# (861, 861)
# B0050_shuriken/B0050_0022.png
# (861, 861)
# ...

# %% [markdown]
# So apparently we have a uniformity in the images, 861 by 861 pixels, which is awesome!   ![](https://media.giphy.com/media/xb8zoHFCKU0Ra/giphy.gif)
# Now we can convert this to a panda dataframe and could start working! Great work.

# %%
np.shape(images)
#So the Kernel is dying if I try to convert it to a pandas dataframe...
#df = pd.DataFrame(images)
# Out:
# (532, 741321)

# %% [markdown]
# We should look if we can see one image at least, lets say the fourth:

# %%
Fourth = images[6].reshape(861,861)
plt.imshow(Fourth)
